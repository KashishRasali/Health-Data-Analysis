# %%
# !pip3 install pandas
# !pip3 install seaborn
# !pip3 install matplib
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 22.0.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -m pip install --upgrade pip' command.
# ERROR: Could not find a version that satisfies the requirement matplib (from versions: none)
# ERROR: No matching distribution found for matplib
# WARNING: You are using pip version 22.0.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -m pip install --upgrade pip' command.
